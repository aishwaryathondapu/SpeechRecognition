# %%
import speech_recognition as sr

# %%
sr.__version__
# Out:
# '3.6.3'

# %%
r=sr.Recognizer()

# %%
mic=sr.Microphone()

# %%
sr.Microphone.list_microphone_names()
# Out:
# ['Built-in Microphone', 'Built-in Output', 'ZoomAudioDevice']

# %%
#mic=sr.Microphone(device_index=0)

# %%
with mic as source:
    audio=r.listen(source)

# %%
try: 
        text = r.recognize_google(audio) 
        print("you said: " + text )
except sr.UnknownValueError:
        print("Google Speech Recognition could not understand audio")
# Out:
# you said: hello

# %%
from googletrans import Translator as gt
translator=gt()
text_after_translation=translator.translate(text, dest='hi')
print(text_after_translation)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-1fb126448212> in <module>
#       1 from googletrans import Translator as gt
#       2 translator=gt()
# ----> 3 text_after_translation=translator.translate(text, dest='hi')
#       4 print(text_after_translation)
#
# /anaconda3/lib/python3.7/site-packages/googletrans/client.py in translate(self, text, dest, src)
#     170
#     171         origin = text
# --> 172         data = self._translate(text, dest, src)
#     173
#     174         # this code will be updated when the format is changed.
#
# /anaconda3/lib/python3.7/site-packages/googletrans/client.py in _translate(self, text, dest, src)
#      73             text = text.decode('utf-8')
#      74
# ---> 75         token = self.token_acquirer.do(text)
#      76         params = utils.build_params(query=text, src=src, dest=dest,
#      77                                     token=token)
#
# /anaconda3/lib/python3.7/site-packages/googletrans/gtoken.py in do(self, text)
#     178
#     179     def do(self, text):
# --> 180         self._update()
#     181         tk = self.acquire(text)
#     182         return tk
#
# /anaconda3/lib/python3.7/site-packages/googletrans/gtoken.py in _update(self)
#      57         r = self.session.get(self.host)
#      58         # this will be the same as python code after stripping out a reserved word 'var'
# ---> 59         code = unicode(self.RE_TKK.search(r.text).group(1)).replace('var ', '')
#      60         # unescape special ascii characters such like a \x3d(=)
#      61         if PY3:  # pragma: no cover
#
# AttributeError: 'NoneType' object has no attribute 'group'

# %%
print(text+" "+text_after_translation.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-86459e87fda1> in <module>
# ----> 1 print(text+" "+text_after_translation.text)
#
# NameError: name 'text_after_translation' is not defined
